# %%
#!conda create --name envmk1
#!conda info --envs

# %%
'''
Local:
/home/mk/requirements
'''
#!pip freeze
#!pip freeze > requirements.txt
# Out:
# '\nLocal:\n/home/mk/requirements\n'

# %%
pip install -qr requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import requests
import io
import os

# %%
fonte = "https://data.brasil.io/dataset/covid19/caso_full.csv.gz"
resposta = requests.get(fonte)
content = resposta.content
print(type(content))
dados = pd.read_csv(io.BytesIO(content), sep=",", compression="gzip", index_col=0, quotechar='"')
dados.to_csv("/home/mk/Documentos/maringa/caso_full.csv", index=True)
dados
# Out:
# <class 'bytes'>
#            city_ibge_code        date  epidemiological_week  \
# city
# São Paulo       3550308.0  2020-02-25                     9
# NaN                  35.0  2020-02-25                     9
# São Paulo       3550308.0  2020-02-26                     9
# NaN                  35.0  2020-02-26                     9
# São Paulo       3550308.0  2020-02-27                     9
# ...                   ...         ...                   ...
# NaN                  43.0  2020-12-28                    53
# NaN                  42.0  2020-12-28                    53
# NaN                  28.0  2020-12-28                    53
# NaN                  35.0  2020-12-28                    53
# NaN                  17.0  2020-12-28                    53
#
#            estimated_population  estimated_population_2019  is_last  \
# city
# São Paulo            12325232.0                 12252023.0    False
# NaN                  46289333.0                 45919049.0    False
# São Paulo            12325232.0                 12252023.0    False
# NaN                  46289333.0                 45919049.0    False
# São Paulo            12325232.0                 12252023.0    False
# ...                         ...                        ...      ...
# NaN                  11422973.0                 11377239.0     True
# NaN                   7252502.0                  7164788.0     True
# NaN                   2318822.0                  2298696.0     True
# NaN                  46289333.0                 45919049.0     True
# NaN                   1590248.0                  1572866.0    False
#
#            is_repeated  last_available_confirmed  \
# city
# São Paulo        False                         1
# NaN              False                         1
# São Paulo        False                         1
# NaN              False                         1
# São Paulo        False                         1
# ...                ...                       ...
# NaN              False                    432241
# NaN              False                    482129
# NaN              False                    110001
# NaN              False                   1427752
# NaN               True                     89410
#
#            last_available_confirmed_per_100k_inhabitants last_available_date  \
# city
# São Paulo                                        0.00811          2020-02-25
# NaN                                              0.00216          2020-02-25
# São Paulo                                        0.00811          2020-02-26
# NaN                                              0.00216          2020-02-26
# São Paulo                                        0.00811          2020-02-27
# ...                                                  ...                 ...
# NaN                                           3783.96237          2020-12-28
# NaN                                           6647.76101          2020-12-28
# NaN                                           4743.83113          2020-12-28
# NaN                                           3084.40824          2020-12-28
# NaN                                           5622.39349          2020-12-27
#
#            last_available_death_rate  last_available_deaths  order_for_place  \
# city
# São Paulo                     0.0000                      0                1
# NaN                           0.0000                      0                1
# São Paulo                     0.0000                      0                2
# NaN                           0.0000                      0                2
# São Paulo                     0.0000                      0                3
# ...                              ...                    ...              ...
# NaN                           0.0197                   8536              294
# NaN                           0.0105                   5082              292
# NaN                           0.0224                   2461              290
# NaN                           0.0321                  45902              308
# NaN                           0.0137                   1226              286
#
#           place_type state  new_confirmed  new_deaths
# city
# São Paulo       city    SP              1           0
# NaN            state    SP              1           0
# São Paulo       city    SP              0           0
# NaN            state    SP              0           0
# São Paulo       city    SP              0           0
# ...              ...   ...            ...         ...
# NaN            state    RS            638          44
# NaN            state    SC           2182          43
# NaN            state    SE           1058           7
# NaN            state    SP           1576          39
# NaN            state    TO              0           0
#
# [1303980 rows x 17 columns]

# %%
cidade1 =  dados.query('city == "Maringá"')
cidade1.to_csv("/home/mk/Documentos/maringa/maringa.csv", index=True)
cidade1
# Out:
#          city_ibge_code        date  epidemiological_week  \
# city
# Maringá       4115200.0  2020-03-18                    12
# Maringá       4115200.0  2020-03-19                    12
# Maringá       4115200.0  2020-03-20                    12
# Maringá       4115200.0  2020-03-21                    12
# Maringá       4115200.0  2020-03-22                    13
# ...                 ...         ...                   ...
# Maringá       4115200.0  2020-12-24                    52
# Maringá       4115200.0  2020-12-25                    52
# Maringá       4115200.0  2020-12-26                    52
# Maringá       4115200.0  2020-12-27                    53
# Maringá       4115200.0  2020-12-28                    53
#
#          estimated_population  estimated_population_2019  is_last  \
# city
# Maringá              430157.0                   423666.0    False
# Maringá              430157.0                   423666.0    False
# Maringá              430157.0                   423666.0    False
# Maringá              430157.0                   423666.0    False
# Maringá              430157.0                   423666.0    False
# ...                       ...                        ...      ...
# Maringá              430157.0                   423666.0    False
# Maringá              430157.0                   423666.0    False
# Maringá              430157.0                   423666.0    False
# Maringá              430157.0                   423666.0    False
# Maringá              430157.0                   423666.0     True
#
#          is_repeated  last_available_confirmed  \
# city
# Maringá        False                         1
# Maringá        False                         1
# Maringá        False                         1
# Maringá        False                         1
# Maringá        False                         1
# ...              ...                       ...
# Maringá        False                     20847
# Maringá        False                     21112
# Maringá        False                     21112
# Maringá        False                     21126
# Maringá        False                     21403
#
#          last_available_confirmed_per_100k_inhabitants last_available_date  \
# city
# Maringá                                        0.23247          2020-03-18
# Maringá                                        0.23247          2020-03-19
# Maringá                                        0.23247          2020-03-20
# Maringá                                        0.23247          2020-03-21
# Maringá                                        0.23247          2020-03-22
# ...                                                ...                 ...
# Maringá                                     4846.37005          2020-12-24
# Maringá                                     4907.97546          2020-12-25
# Maringá                                     4907.97546          2020-12-26
# Maringá                                     4911.23009          2020-12-27
# Maringá                                     4975.62518          2020-12-28
#
#          last_available_death_rate  last_available_deaths  order_for_place  \
# city
# Maringá                     0.0000                      0                1
# Maringá                     0.0000                      0                2
# Maringá                     0.0000                      0                3
# Maringá                     0.0000                      0                4
# Maringá                     0.0000                      0                5
# ...                            ...                    ...              ...
# Maringá                     0.0145                    303              282
# Maringá                     0.0145                    307              283
# Maringá                     0.0145                    307              284
# Maringá                     0.0145                    307              285
# Maringá                     0.0145                    311              286
#
#         place_type state  new_confirmed  new_deaths
# city
# Maringá       city    PR              1           0
# Maringá       city    PR              0           0
# Maringá       city    PR              0           0
# Maringá       city    PR              0           0
# Maringá       city    PR              0           0
# ...            ...   ...            ...         ...
# Maringá       city    PR            291           3
# Maringá       city    PR            265           4
# Maringá       city    PR              0           0
# Maringá       city    PR             14           0
# Maringá       city    PR            277           4
#
# [286 rows x 17 columns]

# %%
cidade_sel1 = cidade1.filter(items=['date', 'last_available_confirmed', 'last_available_deaths'])

# %%
cidade_sel1.T
# Out:
# city                         Maringá     Maringá     Maringá     Maringá  \
# date                      2020-03-18  2020-03-19  2020-03-20  2020-03-21
# last_available_confirmed           1           1           1           1
# last_available_deaths              0           0           0           0
#
# city                         Maringá     Maringá     Maringá     Maringá  \
# date                      2020-03-22  2020-03-23  2020-03-24  2020-03-25
# last_available_confirmed           1           1           1           2
# last_available_deaths              0           0           0           0
#
# city                         Maringá     Maringá  ...     Maringá     Maringá  \
# date                      2020-03-26  2020-03-27  ...  2020-12-19  2020-12-20
# last_available_confirmed           3           7  ...       18992       19431
# last_available_deaths              0           2  ...         279         279
#
# city                         Maringá     Maringá     Maringá     Maringá  \
# date                      2020-12-21  2020-12-22  2020-12-23  2020-12-24
# last_available_confirmed       19871       20264       20556       20847
# last_available_deaths            280         290         300         303
#
# city                         Maringá     Maringá     Maringá     Maringá
# date                      2020-12-25  2020-12-26  2020-12-27  2020-12-28
# last_available_confirmed       21112       21112       21126       21403
# last_available_deaths            307         307         307         311
#
# [3 rows x 286 columns]

# %%
cidade_sel1.to_csv("/home/mk/Documentos/maringa_sel.csv", index=True)

# %%
cidade_sel1.T.to_csv("/home/mk/Documentos/maringa_selT.csv", index=False)

# %%
cidade2 =  dados.query('city == "Londrina"')
cidade2.to_csv("/home/mk/Documentos/maringa/londrina.csv", index=True)
cidade2
# Out:
#           city_ibge_code        date  epidemiological_week  \
# city
# Londrina       4113700.0  2020-03-17                    12
# Londrina       4113700.0  2020-03-18                    12
# Londrina       4113700.0  2020-03-19                    12
# Londrina       4113700.0  2020-03-20                    12
# Londrina       4113700.0  2020-03-21                    12
# ...                  ...         ...                   ...
# Londrina       4113700.0  2020-12-24                    52
# Londrina       4113700.0  2020-12-25                    52
# Londrina       4113700.0  2020-12-26                    52
# Londrina       4113700.0  2020-12-27                    53
# Londrina       4113700.0  2020-12-28                    53
#
#           estimated_population  estimated_population_2019  is_last  \
# city
# Londrina              575377.0                   569733.0    False
# Londrina              575377.0                   569733.0    False
# Londrina              575377.0                   569733.0    False
# Londrina              575377.0                   569733.0    False
# Londrina              575377.0                   569733.0    False
# ...                        ...                        ...      ...
# Londrina              575377.0                   569733.0    False
# Londrina              575377.0                   569733.0    False
# Londrina              575377.0                   569733.0    False
# Londrina              575377.0                   569733.0    False
# Londrina              575377.0                   569733.0     True
#
#           is_repeated  last_available_confirmed  \
# city
# Londrina        False                         1
# Londrina        False                         1
# Londrina        False                         1
# Londrina        False                         3
# Londrina        False                         3
# ...               ...                       ...
# Londrina        False                     21959
# Londrina        False                     22140
# Londrina        False                     22196
# Londrina        False                     22330
# Londrina        False                     22500
#
#           last_available_confirmed_per_100k_inhabitants last_available_date  \
# city
# Londrina                                        0.17380          2020-03-17
# Londrina                                        0.17380          2020-03-18
# Londrina                                        0.17380          2020-03-19
# Londrina                                        0.52140          2020-03-20
# Londrina                                        0.52140          2020-03-21
# ...                                                 ...                 ...
# Londrina                                     3816.45426          2020-12-24
# Londrina                                     3847.91189          2020-12-25
# Londrina                                     3857.64464          2020-12-26
# Londrina                                     3880.93372          2020-12-27
# Londrina                                     3910.47956          2020-12-28
#
#           last_available_death_rate  last_available_deaths  order_for_place  \
# city
# Londrina                     0.0000                      0                1
# Londrina                     0.0000                      0                2
# Londrina                     0.0000                      0                3
# Londrina                     0.0000                      0                4
# Londrina                     0.0000                      0                5
# ...                             ...                    ...              ...
# Londrina                     0.0173                    379              283
# Londrina                     0.0171                    379              284
# Londrina                     0.0171                    379              285
# Londrina                     0.0170                    379              286
# Londrina                     0.0168                    379              287
#
#          place_type state  new_confirmed  new_deaths
# city
# Londrina       city    PR              1           0
# Londrina       city    PR              0           0
# Londrina       city    PR              0           0
# Londrina       city    PR              2           0
# Londrina       city    PR              0           0
# ...             ...   ...            ...         ...
# Londrina       city    PR            361           0
# Londrina       city    PR            181           0
# Londrina       city    PR             56           0
# Londrina       city    PR            134           0
# Londrina       city    PR            170           0
#
# [287 rows x 17 columns]

# %%
cidade_sel2 = cidade2.filter(items=['date', 'last_available_confirmed', 'last_available_deaths'])

# %%
cidade_sel2.T
# Out:
# city                        Londrina    Londrina    Londrina    Londrina  \
# date                      2020-03-17  2020-03-18  2020-03-19  2020-03-20
# last_available_confirmed           1           1           1           3
# last_available_deaths              0           0           0           0
#
# city                        Londrina    Londrina    Londrina    Londrina  \
# date                      2020-03-21  2020-03-22  2020-03-23  2020-03-24
# last_available_confirmed           3           3           3           3
# last_available_deaths              0           0           0           0
#
# city                        Londrina    Londrina  ...    Londrina    Londrina  \
# date                      2020-03-25  2020-03-26  ...  2020-12-19  2020-12-20
# last_available_confirmed           3           3  ...       20290       20508
# last_available_deaths              0           0  ...         377         377
#
# city                        Londrina    Londrina    Londrina    Londrina  \
# date                      2020-12-21  2020-12-22  2020-12-23  2020-12-24
# last_available_confirmed       20632       21198       21598       21959
# last_available_deaths            377         378         379         379
#
# city                        Londrina    Londrina    Londrina    Londrina
# date                      2020-12-25  2020-12-26  2020-12-27  2020-12-28
# last_available_confirmed       22140       22196       22330       22500
# last_available_deaths            379         379         379         379
#
# [3 rows x 287 columns]

# %%
cidade_sel2.to_csv("/home/mk/Documentos/londrina_sel.csv", index=True)

# %%
cidade_sel1.T.to_csv("/home/mk/Documentos/maringa_selT.csv", index=False)

# %%
frames = [cidade_sel1, cidade_sel2]
final = pd.concat(frames)
final = final.T

# %%
final.to_csv("/home/mk/Documentos/maringa/final.csv", index=True)

# %%
os.system('spd-say "Murilo Krominski"')
# Out:
# 0
